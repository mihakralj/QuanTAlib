// %%
#r "nuget: QuanTAlib;"
#r "nuget: Plotly.NET;"
#r "nuget: Plotly.NET.Interactive;"

using QuanTAlib;
using Plotly.NET;
using Plotly.NET.LayoutObjects;
// Out:
// <div><div></div><div></div><div></div></div>
// Loading extensions from `Plotly.NET.Interactive.dll`

// %%
Yahoo_Feed data = new(Symbol: "MSFT", Period: 200);
ZLEMA_Series calc1 = new(data.OHLC4,20,true);
HMA_Series calc2 = new(data.OHLC4,20, true);
HEMA_Series calc3 = new(data.OHLC4,20, true);

// %%
var layout = Layout.init<IConvertible>( 
    PlotBGColor : Color.fromString("#1e1e1e"),
    PaperBGColor : Color.fromString("#1e1e1e"),
    Font:Font.init(Size:10, Color: Color.fromString("#ffffff")));

var yAxis = LinearAxis.init<IConvertible, IConvertible, IConvertible, IConvertible, IConvertible, IConvertible>(
    GridColor:Color.fromString("#252525")); 

var candles = Chart2D.Chart.Candlestick<double, double, double, double, DateTime, string>(data.Open.v, data.High.v, data.Low.v, data.Close.v, data.Open.t, "");
var line1 = Chart2D.Chart.Line<DateTime,double,bool>(calc1.t, calc1.v,false,"").WithLineStyle(Width: 2, Color: Color.fromString("yellow"));
var line2 = Chart2D.Chart.Line<DateTime,double,bool>(calc2.t, calc2.v, false,"").WithLineStyle(Width: 3, Color: Color.fromString("red"));
var line3 = Chart2D.Chart.Line<DateTime,double,bool>(calc3.t, calc3.v, false,"").WithLineStyle(Width: 2, Color: Color.fromString("blue"));
var chart = Chart.Combine(new []{candles, line1, line2, line3})
    .WithSize(1200,600)
    .WithMargin(Margin.init<int, int, int, int, int, bool>(30,10,40,30,1,false))
    .WithXAxisRangeSlider(RangeSlider.init(Visible:false))
    .WithYAxis(yAxis)
    .WithXAxis(yAxis)
    .WithTitle("MSFT")
    .WithLayout(layout);

chart
// Out:
// <div>
//     <div id="34d44d07-fcaa-4072-9017-5faa3448ff33"><!-- Plotly chart will be drawn inside this DIV --></div>
// <script type="text/javascript">
//
//             var renderPlotly_34d44d07fcaa407290175faa3448ff33 = function() {
//             var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-2.6.3.min'}}) || require;
//             fsharpPlotlyRequire(['plotly'], function(Plotly) {
//
//             var data = [{"type":"candlestick","name":"","x":["2022-04-26T13:30:00","2022-04-27T13:30:00","2022-04-28T13:30:00","2022-04-29T13:30:00","2022-05-02T13:30:00","2022-05-03T13:30:00","2022-05-04T13:30:00","2022-05-05T13:30:00","2022-05-06T13:30:00","2022-05-09T13:30:00","2022-05-10T13:30:00","2022-05-11T13:30:00","2022-05-12T13:30:00","2022-05-13T13:30:00","2022-05-16T13:30:00","2022-05-17T13:30:00","2022-05-18T13:30:00","2022-05-19T13:30:00","2022-05-20T13:30:00","2022-05-23T13:30:00","2022-05-24T13:30:00","2022-05-25T13:30:00","2022-05-26T13:30:00","2022-05-27T13:30:00","2022-05-31T13:30:00","2022-06-01T13:30:00","2022-06-02T13:30:00","2022-06-03T13:30:00","2022-06-06T13:30:00","2022-06-07T13:30:00","2022-06-08T13:30:00","2022-06-09T13:30:00","2022-06-10T13:30:00","2022-06-13T13:30:00","2022-06-14T13:30:00","2022-06-15T13:30:00","2022-06-16T13:30:00","2022-06-17T13:30:00","2022-06-21T13:30:00","2022-06-22T13:30:00","2022-06-23T13:30:00","2022-06-24T13:30:00","2022-06-27T13:30:00","2022-06-28T13:30:00","2022-06-29T13: